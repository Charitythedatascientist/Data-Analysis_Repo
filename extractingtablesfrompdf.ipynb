# %%
pip install tabula-py
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.3.2 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import tabula

# %%
pdf_path = "Nagano data center usage fee(2023-10)_INVOICE.pdf"

# %%
dfs = tabula.read_pdf(pdf_path, pages = "1")

# %%
dfs[0]
# Out:
#                                     Description   Qty.  Unnamed: 0  Unit  \
# 0   Internet connectivity fee (9000Mbps commit)    1.0         NaN   mth
# 1                                    IP address   10.0         NaN    IP
# 2                 Internet Connecting overusage  462.0         NaN  Mbps
# 3                                           NaN    NaN         NaN   NaN
# 4                                   Power Usage    NaN         NaN   NaN
# 5                                    D1 PDU/mth   29.2         NaN     A
# 6                                    D2 PDU/mth   26.4         NaN     A
# 7                                    D3 PDU/mth   44.8         NaN     A
# 8                                    D4 PDU/mth   36.8         NaN     A
# 9                                    D5 PDU/mth   33.0         NaN     A
# 10                                   D6 PDU/mth   24.0         NaN     A
# 11                                          NaN    NaN         NaN   NaN
# ...

# %%
dfs[1].to_csv("table_1.csv")
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 dfs[1].to_csv("table_1.csv")
#
# IndexError: list index out of range

# %%
print(len(dfs))
# Out:
# 1

# %% [markdown]
# method 2

# %%
tabula.convert_into(pdf_path, "first_table_2.csv", output_format = "csv", pages = "1")

# %%
#many tables:

# %%
for i in range(len(dfs)):
    dfs[i].to_csv(f"page_2_table{i}.csv")

# %%
for i in range(len(dfs)):
    print(dfs)
# Out:
# [                                    Description   Qty.  Unnamed: 0  Unit  \
# 0   Internet connectivity fee (9000Mbps commit)    1.0         NaN   mth
# 1                                    IP address   10.0         NaN    IP
# 2                 Internet Connecting overusage  462.0         NaN  Mbps
# 3                                           NaN    NaN         NaN   NaN
# 4                                   Power Usage    NaN         NaN   NaN
# 5                                    D1 PDU/mth   29.2         NaN     A
# 6                                    D2 PDU/mth   26.4         NaN     A
# 7                                    D3 PDU/mth   44.8         NaN     A
# 8                                    D4 PDU/mth   36.8         NaN     A
# 9                                    D5 PDU/mth   33.0         NaN     A
# 10                                   D6 PDU/mth   24.0         NaN     A
# 11                                          NaN    NaN         NaN   NaN
# ...

# %%
#Many tables in one pdf file

# %%
for i in range(len(dfs)):
    dfs[i].to_csv(f"all_pages_table{i}.csv")
